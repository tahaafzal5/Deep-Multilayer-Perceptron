# %%
import sys
assert sys.version_info >= (3, 5)

import tensorflow as tf
assert tf.__version__ >= "2.0"
from tensorflow import keras

import numpy as np
import os

np.random.seed(42)

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Load the dataset:

(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
# The MNIST training set contains 60,000 grayscale images, each 28x28 pixels:

X_train_full.shape
# Out:
# (60000, 28, 28)

# %%
# Each pixel intensity is represented as a byte (0 to 255):

X_train_full.dtype
# Out:
# dtype('uint8')

# %%
# Split the full training set into a validation set and a (smaller) training set. 
# We also scale the pixel intensities down to the 0-1 range and convert them to floats, by dividing by 255:

X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.

# %%
# Plot an image using Matplotlib's imshow() function, with a 'binary' color map:

plt.imshow(X_train[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
# The labels are the class IDs (represented as uint8), from 0 to 9. 
# Conveniently, the class IDs correspond to the digits represented in the images, so we don't need a class_names array:

y_train
# Out:
# array([7, 3, 4, ..., 5, 6, 8], dtype=uint8)

# %%
# The validation set contains 5,000 images, and the test set contains 10,000 images:

X_valid.shape
# Out:
# (5000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
# A look at a sample of the images in the dataset:

n_rows = 4
n_cols = 10
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(y_train[index], fontsize=12)
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %%
# Building a simple dense network and find the optimal learning rate. 
# We will need a callback to grow the learning rate at each iteration. 
# It will also record the learning rate and the loss at each iteration:

K = keras.backend

class ExponentialLearningRate(keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []
    def on_batch_end(self, batch, logs):
        self.rateskeras.backend.clear_session()
np.random.seed(42)

tf.random.set_seed(42).append(K.get_value(self.model.optimizer.lr))
        self.losses.append(logs["loss"])
        K.set_value(self.model.optimizer.lr, self.model.optimizer.lr * self.factor)

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

# %%
# Start with a small learning rate of 1e-3, and grow it by 0.5% at each iteration:

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-3),
              metrics=["accuracy"])
expon_lr = ExponentialLearningRate(factor=1.005)

# %%
# Train the model for just 1 epoch:

history = model.fit(X_train, y_train, epochs=1,
                    validation_data=(X_valid, y_valid),
                    callbacks=[expon_lr])
# Out:
# Train on 55000 samples, validate on 5000 samples
# 55000/55000 [==============================] - 4s 68us/sample - loss: nan - accuracy: 0.5818 - val_loss: nan - val_accuracy: 0.0958

# %%
# Plotting the loss as a function of the learning rate:

plt.plot(expon_lr.rates, expon_lr.losses)
plt.gca().set_xscale('log')
plt.hlines(min(expon_lr.losses), min(expon_lr.rates), max(expon_lr.rates))
plt.axis([min(expon_lr.rates), max(expon_lr.rates), 0, expon_lr.losses[0]])
plt.xlabel("Learning rate")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=2e-1),
              metrics=["accuracy"])

# %%
run_index = 1 # increment this at every run
run_logdir = os.path.join(os.curdir, "my_mnist_logs", "run_{:03d}".format(run_index))
run_logdir
# Out:
# '.\\my_mnist_logs\\run_001'

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=20)
checkpoint_cb = keras.callbacks.ModelCheckpoint("my_mnist_model.h5", save_best_only=True)

history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid),
                    callbacks=[early_stopping_cb, checkpoint_cb])
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/100
# 55000/55000 [==============================] - 3s 55us/sample - loss: 0.0182 - accuracy: 0.9946 - val_loss: 0.0823 - val_accuracy: 0.9810
# Epoch 2/100
# 55000/55000 [==============================] - 3s 53us/sample - loss: 0.0151 - accuracy: 0.9952 - val_loss: 0.0720 - val_accuracy: 0.9840
# Epoch 3/100
# 55000/55000 [==============================] - 3s 54us/sample - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.0776 - val_accuracy: 0.9808
# Epoch 4/100
# 55000/55000 [==============================] - 3s 52us/sample - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.0857 - val_accuracy: 0.9798
# Epoch 5/100
# 55000/55000 [==============================] - 3s 51us/sample - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0707 - val_accuracy: 0.9860
# Epoch 6/100
# 55000/55000 [==============================] - 3s 51us/sample - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0728 - val_accuracy: 0.9844
# Epoch 7/100
# 55000/55000 [==============================] - 3s 51us/sample - loss: 6.5107e-04 - accuracy: 1.0000 - val_loss: 0.0720 - val_accuracy: 0.9868
# Epoch 8/100
# 55000/55000 [==============================] - 3s 50us/sample - loss: 4.3754e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9866
# Epoch 9/100
# 55000/55000 [==============================] - 3s 50us/sample - loss: 2.8584e-04 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9858
# Epoch 10/100
# 55000/55000 [==============================] - 3s 49us/sample - loss: 2.1021e-04 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 0.9858
# Epoch 11/100
# 55000/55000 [==============================] - 3s 52us/sample - loss: 1.8374e-04 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9860
# Epoch 12/100
# 55000/55000 [==============================] - 3s 49us/sample - loss: 1.6412e-04 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 0.9860
# Epoch 13/100
# 55000/55000 [==============================] - 3s 50us/sample - loss: 1.4934e-04 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9858
# Epoch 14/100
# 55000/55000 [==============================] - 3s 49us/sample - loss: 1.3805e-04 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9858
# Epoch 15/100
# 55000/55000 [==============================] - 3s 52us/sample - loss: 1.2714e-04 - accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 0.9858
# Epoch 16/100
# 55000/55000 [==============================] - 3s 50us/sample - loss: 1.1899e-04 - accuracy: 1.0000 - val_loss: 0.0804 - val_accuracy: 0.9858
# Epoch 17/100
# 55000/55000 [==============================] - 3s 49us/sample - loss: 1.1194e-04 - accuracy: 1.0000 - val_loss: 0.0808 - val_accuracy: 0.9860
# Epoch 18/100
# 55000/55000 [==============================] - 3s 49us/sample - loss: 1.0502e-04 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 0.9858
# Epoch 19/100
# 55000/55000 [==============================] - 3s 52us/sample - loss: 9.9832e-05 - accuracy: 1.0000 - val_loss: 0.0821 - val_accuracy: 0.9862
# Epoch 20/100
# 55000/55000 [==============================] - 3s 49us/sample - loss: 9.4332e-05 - accuracy: 1.0000 - val_loss: 0.0822 - val_accuracy: 0.9856
# Epoch 21/100
# 55000/55000 [==============================] - 3s 48us/sample - loss: 9.0187e-05 - accuracy: 1.0000 - val_loss: 0.0824 - val_accuracy: 0.9858
# Epoch 22/100
# 55000/55000 [==============================] - 3s 51us/sample - loss: 8.6433e-05 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 0.9860
# Epoch 23/100
# 55000/55000 [==============================] - 3s 51us/sample - loss: 8.2563e-05 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 0.9858
# Epoch 24/100
# 55000/55000 [==============================] - 3s 48us/sample - loss: 7.8964e-05 - accuracy: 1.0000 - val_loss: 0.0838 - val_accuracy: 0.9860
# Epoch 25/100
# 55000/55000 [==============================] - 3s 49us/sample - loss: 7.5936e-05 - accuracy: 1.0000 - val_loss: 0.0841 - val_accuracy: 0.9860

# %%
model = keras.models.load_model("my_mnist_model.h5") # rollback to best model
model.evaluate(X_test, y_test)
# Out:
# 10000/10000 [==============================] - 0s 35us/sample - loss: 0.0795 - accuracy: 0.9812
# [0.07945523627818857, 0.9812]

# %%
# Answer the following questions:

#   What are the dimensions of this deep network? (that is, what is the size of the input, hidden, and output layers)?
#       We have 1 input Flatten layer that converts each input image into a 1D array: if it receives input data X, 
#       it computes X.reshape(-1, 1)
#       Next we have a Dense hidden layer with 300 neurons and a second Dense hidden layer with 100 neurons.
#       Then we have a Dense output layer with 10 neurons (one per class)

#   What activation functions are used here?
#       The 2 Dense hidden layers use the ReLU activation function.
#       The Dense output layer uses the softmax activation function.

#   Why is there a softmax layer?
#        We have a softmax layer because the classes are exclusive. This ensures that that all the estimated probabilities are
#        betweeen 0 and 1 and they add up to 1.

#   What accuracy did you observe when the test data was checked?
#       I got an accuracy of 98.12%
